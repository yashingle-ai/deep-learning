# %%
"""Input (1 × 28 × 28)
↓
Conv (3×3, 8 filters)
↓
ReLU
↓
MaxPool (2×2)
↓
Flatten
↓
Dense (128)
↓
Dense (10)
↓
Softmax
  """

# %%
import numpy as np 


class Conv2d:

    def __init__(self,num_filters,filter_size)
